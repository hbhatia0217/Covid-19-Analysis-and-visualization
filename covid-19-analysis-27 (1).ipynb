# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
df =  pd.read_csv('owid-covid-data.csv')
df.head(10)
# Out:
#   iso_code      continent location       date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  3/13/2020          2.0        2.0
# 1      ABW  North America    Aruba  3/19/2020          NaN        NaN
# 2      ABW  North America    Aruba  3/20/2020          4.0        2.0
# 3      ABW  North America    Aruba  3/21/2020          NaN        NaN
# 4      ABW  North America    Aruba  3/22/2020          NaN        NaN
# 5      ABW  North America    Aruba  3/23/2020          NaN        NaN
# 6      ABW  North America    Aruba  3/24/2020         12.0        8.0
# 7      ABW  North America    Aruba  3/25/2020         17.0        5.0
# 8      ABW  North America    Aruba  3/26/2020         19.0        2.0
# 9      ABW  North America    Aruba  3/27/2020         28.0        9.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# ...

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed   total_deaths  \
# count  3.806200e+04   37891.000000        37110.000000   38062.000000
# mean   6.820226e+04    1198.471669         1182.486619    3174.823499
# std    7.046395e+05   11066.159664        10839.228254   29884.394398
# min    0.000000e+00   -2461.000000         -338.857000       0.000000
# 25%    2.900000e+01       0.000000            0.429000       0.000000
# 50%    6.860000e+02       7.000000           11.143000      11.000000
# 75%    7.234750e+03     128.000000          132.000000     146.000000
# max    2.270564e+07  298097.000000       263454.429000  794104.000000
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  37891.000000         37110.000000             37827.000000
# mean      41.915178            41.840320              1376.011221
# std      360.165230           349.291799              3141.537124
# min    -1918.000000          -232.143000                 0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38638 entries, 0 to 38637
# Data columns (total 40 columns):
# iso_code                           38403 non-null object
# continent                          38168 non-null object
# location                           38638 non-null object
# date                               38638 non-null object
# total_cases                        38062 non-null float64
# new_cases                          37891 non-null float64
# new_cases_smoothed                 37110 non-null float64
# total_deaths                       38062 non-null float64
# new_deaths                         37891 non-null float64
# new_deaths_smoothed                37110 non-null float64
# total_cases_per_million            37827 non-null float64
# new_cases_per_million              37827 non-null float64
# new_cases_smoothed_per_million     37045 non-null float64
# total_deaths_per_million           37827 non-null float64
# ...

# %%
df.drop(['new_cases_smoothed','new_deaths_smoothed','new_cases_smoothed_per_million','new_deaths_smoothed_per_million','new_tests_smoothed_per_thousand'],axis = 1,inplace=True)
df.head(5)
# Out:
#   iso_code      continent location       date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  3/13/2020          2.0        2.0
# 1      ABW  North America    Aruba  3/19/2020          NaN        NaN
# 2      ABW  North America    Aruba  3/20/2020          4.0        2.0
# 3      ABW  North America    Aruba  3/21/2020          NaN        NaN
# 4      ABW  North America    Aruba  3/22/2020          NaN        NaN
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0.0         0.0                   18.733                 18.733
# 1           NaN         NaN                      NaN                    NaN
# 2           0.0         0.0                   37.465                 18.733
# 3           NaN         NaN                      NaN                    NaN
# 4           NaN         NaN                      NaN                    NaN
#
#    ...  aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                        235
# continent                       470
# location                          0
# date                              0
# total_cases                     576
# new_cases                       747
# total_deaths                    576
# new_deaths                      747
# total_cases_per_million         811
# new_cases_per_million           811
# total_deaths_per_million        811
# new_deaths_per_million          811
# new_tests                     26276
# total_tests                   25952
# total_tests_per_thousand      25952
# new_tests_per_thousand        26276
# new_tests_smoothed            24771
# tests_per_case                25857
# positive_rate                 25500
# tests_units                   24016
# stringency_index               6664
# population                      235
# population_density             1935
# median_age                     4108
# aged_65_older                  4613
# aged_70_older                  4286
# ...

# %%
df.shape
# Out:
# (38638, 35)

# %%
max(df['date'])
# Out:
# '8/9/2020'

# %% [markdown]
# # Data Structure
#
# This dataset has 38638 rows and 35 columns from March 13.
# MIn date of the dataset is '1/1/2020'
# Max date of the dataset is '8/9/2020'

# %% [markdown]
# # Following question interset me from this dataset
# a) which continent has most and least cases reported in the world.
# b) In which month most cases were reported in United States.
# c) Mean of new cases
# d) In United States which month had most cases reported.

# %%
df = df.fillna("")

# %%
df.shape
# Out:
# (38638, 35)

# %%
plt.figure(figsize=(12,8))
n_points = df.shape[0]
max_count = df['continent'].value_counts().max()
max_prop = max_count / n_points
#df = df['total_cases'].astype(str)
# data = np.array(data, dtype=np.float32)
case_props = np.arange(0, max_prop,0.05)
case_names = ['{:0.2f}'.format(v) for v in case_props]
#bin_edges.astype(str)
base_color = sb.color_palette()[0]
sb.countplot(data = df, x = 'continent', color = base_color)
plt.yticks(case_props * n_points, case_names)
plt.ylabel('proportion')
#plt.text(v, ha = 'center', color = 'w')
# Out:
# Text(0, 0.5, 'proportion')

# %%
plt.figure(figsize=(14,10))
base_color = sb.color_palette()[0]
sb.countplot(data = df, x = 'continent', color = base_color)

# add annotations
n_points = df.shape[0]
cat_counts = df['continent'].value_counts()
locs, labels = plt.xticks() # get the current tick locations and labels

# loop through each pair of locations and labels
for loc, label in zip(locs, labels):

    # get the text property for the label to get the correct count
    count = cat_counts[label.get_text()]
    pct_string = '{:0.1f}%'.format(100*count/n_points)

    # print the annotation just below the top of the bar
    plt.text(loc, count-8, pct_string, ha = 'center', color = 'w')

# %% [markdown]
# # Q) which continent has most and least cases reported in the world
#
# - Overall, Europeon continent has most cases.
# - Oceania continent has least cases.

# %%
df_us = df.loc[df['location'].isin(['United States'])]
df_us
# Out:
#       iso_code      continent       location        date  total_cases  \
# 35958      USA  North America  United States  12/31/2019            0
# 35959      USA  North America  United States    1/1/2020            0
# 35960      USA  North America  United States    1/2/2020            0
# 35961      USA  North America  United States    1/3/2020            0
# 35962      USA  North America  United States    1/4/2020            0
# 35963      USA  North America  United States    1/5/2020            0
# 35964      USA  North America  United States    1/6/2020            0
# 35965      USA  North America  United States    1/7/2020            0
# 35966      USA  North America  United States    1/8/2020            0
# 35967      USA  North America  United States    1/9/2020            0
# 35968      USA  North America  United States   1/10/2020            0
# 35969      USA  North America  United States   1/11/2020            0
# ...

# %%
df_us.describe()
# Out:
#        iso_code      continent       location       date  total_cases  \
# count       235            235            235        235        235.0
# unique        1              1              1        235        192.0
# top         USA  North America  United States  7/13/2020          0.0
# freq        235            235            235          1         21.0
#
#         new_cases  total_deaths  new_deaths  total_cases_per_million  \
# count       235.0         235.0       235.0                    235.0
# unique      179.0         174.0       161.0                    192.0
# top           0.0           0.0         0.0                      0.0
# freq         44.0          61.0        62.0                     21.0
#
#         new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
# count                   235.0  ...        235.000         235.000
# unique                  179.0  ...          1.000           1.000
# top                       0.0  ...          9.732       54225.446
# ...

# %%
df_us['new_cases'].mean()
# Out:
# 23718.497872340424

# %% [markdown]
# # Creating Bivariated analysis
# In this analysis, I would analyze which month had most and least Covid-19 cases amongst all continents.

# %%
#Performing data analysis by total number of cases in a month. 

df['month'] = pd.DatetimeIndex(df['date']).month
df['month'].value_counts()
# Out:
# 7     6542
# 5     6527
# 6     6331
# 4     6188
# 8     4441
# 3     4332
# 1     2111
# 2     2098
# 12      68
# Name: month, dtype: int64

# %% [markdown]
# #Analysis on cases reported
# * Based on the above, graph depicts Africa reported covid cases from different regions 1155 times.
# * Oceania continents reported cases 168 times in last 21 days from different locations.

# %%
df['total_cases'].dtype
# Out:
# dtype('O')

# %%
df
# Out:
#       iso_code      continent       location       date total_cases new_cases  \
# 0          ABW  North America          Aruba  3/13/2020           2         2
# 1          ABW  North America          Aruba  3/19/2020
# 2          ABW  North America          Aruba  3/20/2020           4         2
# 3          ABW  North America          Aruba  3/21/2020
# 4          ABW  North America          Aruba  3/22/2020
# 5          ABW  North America          Aruba  3/23/2020
# 6          ABW  North America          Aruba  3/24/2020          12         8
# 7          ABW  North America          Aruba  3/25/2020          17         5
# 8          ABW  North America          Aruba  3/26/2020          19         2
# 9          ABW  North America          Aruba  3/27/2020          28         9
# 10         ABW  North America          Aruba  3/28/2020          28         0
# 11         ABW  North America          Aruba  3/29/2020          28         0
# ...

# %%
#df = df.explode('total_cases')
#df['total_cases'] = df['total_cases'].astype(float)
base_color = sb.color_palette()[0]
sb.violinplot(data = df, x ='continent', y='month',color = base_color)
plt.xticks(rotation=15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
#df['new_cases'] = df['new_cases'].astype(str).astype(int)

plt.figure(figsize = [16, 8])
base_color = sb.color_palette()[0]

# left plot: violin plot
plt.subplot(1, 2, 1)
ax1 = sb.violinplot(data = df, x = 'continent', y = 'month', color = base_color)

# right plot: box plot
plt.subplot(1, 2, 2)
sb.boxplot(data = df, x = 'continent', y = 'month', color = base_color)

# %% [markdown]
# # Creating Multivariated analysis
# In this analysis, I would analyze which month had most and least Covid-19 cases amongst all continents.

# %%
plt.figure(figsize = [16,12])
df["total_cases"] = pd.to_numeric(df["total_cases"])
cases = df.loc[df['continent'].isin(['North America','Asia','Africa','Oceania','South America','Europe'])]
g = sb.FacetGrid(data = df, hue = 'continent',height= 5)
g=g.map(plt.scatter,'total_cases','month')
g.set(xscale = 'log')
xticks = [100,3000,100000,600000]
g.set(xticks = xticks,xticklabels =xticks)
plt.legend(['North America','Asia','Africa','Oceania','South America','Europe'])

# %% [markdown]
# # Explanatory Analysis with multivariated analysis
#
# 1st Analysis: Perform polishing and cleaning steps for the following multivariate plot,
# where the relationship between total_cases and new_cases are depicted for
# the India and Mexico types.
#
# In below analysis, it shows total cases in Mexico were increasing at much faster pace in April than in India.
# However, by August of this year total cases in India were almost 2 million
# whereas total cases in Mexico were close to 500000 which is 150% more
# than cases in India

# %%
# data processing: isolate only fairy and dragon type Pokemon
df =  pd.read_csv('owid-covid-data.csv')
df['month'] = pd.DatetimeIndex(df['date']).month
place_cols = ['continent','location']
non_place_cols = df.columns.difference(place_cols)
place_types = df.melt(id_vars = non_place_cols, value_vars = place_cols, 
                          var_name = 'place_type', value_name = 'place').dropna()
#print(pkmn_types)

place_sub = place_types.loc[place_types['place'].isin(['India','Mexico'])]

place_colors = {'India': '#ee99ac', 'Mexico': '#7038f8'}

# %%
# MODIFY THIS CODE
plt.figure(figsize = [16, 8])
g = sb.FacetGrid(data = place_sub, hue = 'place', height = 5,palette = place_colors)
g.map(plt.scatter,'total_cases','month')
g.set(xscale = 'log')
x_ticks = [1000, 3000, 10000, 30000, 150000, 500000]
g.set(xticks = x_ticks, xticklabels = x_ticks)

# add labels and titles
g.set_xlabels('total_cases')
g.set_ylabels('month')
plt.title('Comparison Of Total Cases From March ill August between India and Mexico')
plt.legend(['India', 'Mexico'], title = 'Covid Cases by Months between India and Mexico')

# %%
# Created heatmap to show which continent has which continent 
#has most deaths between Jan till August. Based on below analysis, month of August had most 
#total number of deaths in the world with the mean of 366K followed by June.

sb.set(font_scale=.75)
df["total_deaths"] = pd.to_numeric(df["total_deaths"])
df["new_cases"] = pd.to_numeric(df["new_cases"])
#cases = df.loc[df['continent'].isin(['North America','Asia'])]
case_means = df.groupby(['continent', 'month']).mean()['total_deaths']
case_means = case_means.reset_index(name = 'total_deaths_avg')
case_means = case_means.pivot(index = 'month', columns = 'continent',
                            values = 'total_deaths_avg')
sb.heatmap(case_means, annot = True, fmt = '.3f',
           cbar_kws = {'label' : 'mean(total_deaths)'})

# %% [markdown]
# 2nd Analysis:Created heatmap to show which continent has which continent
# has most deaths between Jan till August. Based on below analysis, month of August had most
# total number of deaths in the world with the mean of 366K followed by June.
